# %%
import cv2
import pytesseract
import numpy as np
import matplotlib.pyplot as plt
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
image = cv2.imread(r"C:\Users\Carlt\Documents\phoenix\test\ocr\test.JPG",0)
plt.imshow(image)

# %%
denoised = cv2.medianBlur(image, 3)
plt.imshow(denoised)

# %%
equalized = 
plt.imshow(equalized)

# %%
threshold = cv2.adaptiveThreshold(equalized, 128, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 11, 2)
plt.imshow(threshold)

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (2, 2))
plt.imshow(kernel)

# %%
dilated = cv2.dilate(threshold, kernel, iterations=2)
plt.imshow(dilated)

# %%
for i in range(4,11):
    text = pytesseract.image_to_string(dilated,config=f'--psm {i}')
    print(f"Texte extrait de l'image {i}:")
    print(f'|{text}|')
# Out:
# Texte extrait de l'image 4:
# ||
# Texte extrait de l'image 5:
# |A ANS Cate
# pele ele 25]
# en ee
# alge pes
# ssa Serer
# Joos & as doe
# Bey ms LO
# oon
# eg line
# Soh as Ses
# 12 ty Se BY
# Serr eee
# Cy ass
# oe ee?
# aia |
# seh tid
# sree ones ©
# eet irate
# TERS EN
# eae TY
# SF ergy Me
# Seeecetcs
# ne LO
# Pana)
# gai Mars
# Spel ey
# ey poe
# SEE
# at ae
# ye we
# Ay coe
# Ve pee?
# Wy cee
# Sed:
# tase Paeee ih
# |
# Texte extrait de l'image 6:
# |Pe ee be ee de a ee de wb
# ERTL Soa stab dR Oe Sees ee
# Z Pe Satre Sols ere seen oan aes HE en
# GReh AY Pewee eee renee age yh
# LN AT oe eae Bee ot ye eg, See ee yO
# Omg nete Siam e iat nese hE nt
# eB pap are CLI SE BA Ud 6
# SH PEE SE EN ioe eee re ONS ed
# ae era oe Set an TOA Te Pe rg tt on LR
#
# WEP ATR REA Oe ae eta or a
# |
# Texte extrait de l'image 7:
# ||
# Texte extrait de l'image 8:
# |ene
# |
# Texte extrait de l'image 9:
# |ene
# |
# Texte extrait de l'image 10:
# |ene
# |
